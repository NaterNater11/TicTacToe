# %%
# Setting up environment
import pygame as py
import random
import time
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def Coin_Flip(running, font):
    
    # Randomly choses heads or tails
    flip = random.randint(1, 2)
    player = 0
    
    # Screen for coin flip
    screen.fill("beige")
    
    
    # Buttons
    

    
    
    # Simulates coin flip to determine who plays first

    while running and player == 0:
        # Instrcutions to end program
        for event in py.event.get():
            if event.type == py.QUIT:
                running = False

            # waits for player to pick heads or tails
      
    
    # Creates coin background
    py.draw.circle(screen, 'yellow', [300, 180], 150, 0) 
        
    # Coin landed on heads
    if flip == 1:
        head = font.render('HEADS', True, 'black')
        screen.blit(head, (300,180))
        
        
    # Coin landed on tails
    else:
        tail = font.render('TAILS', True, 'black')
        screen.blit(tail, (300,180))
        
    py.display.update()
        
        
    
    # Tells user whether they won or lost
    if flip == player:
        # Player has guessed the flip correctly
        text = font.render('You will play first', True, 'black')
        time.sleep(15)
        return (1)
        
    else:
        # Coin landed on other side
        text = font.render('You will play second', True, 'black')
        time.sleep(15)
        return (2)

# %%
# Basic Setup
py.init()
py.font.init()
screen = py.display.set_mode((601, 400))
running = True


# Displaying Text
font = py.font.SysFont('timesnewroman.ttf', 30)
text = font.render('Give me an X, Give me an O, Give me a Three in a Row', True, 'black')


# Menu Screen (may need to start function here)
game = 0
screen.fill("beige")
py.display.set_caption('Tic Tac Toe')
screen.blit(text, (30,350))


# Buttons





py.display.update()


# Gamemode selection
while running and game == 0:
    # Instrcutions to end program
    for event in py.event.get():
        if event.type == py.QUIT:
            running = False
            
            
            
            
"""        
#Calls coin flip function
if game != 1:
    first = Coin_Flip(running, font)
            
    

# Print background colour and grid for game
screen.fill("beige")

# Vertical lines
x = 0
while x <= 600:
    py.draw.line(screen, "black", (x, 0), (x, 404))
    x += 200
    
# Horizontal lines
y = 0
while y <= 404:
    py.draw.line(screen, "black", (0, y), (600, y))
    y += 133
    
py.display.update()


# Visuals for screen
while running:
    # Instrcutions to end program
    for event in py.event.get():
        if event.type == py.QUIT:
            running = False
            
    
    
    
            
"""   
py.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       4 screen = py.display.set_mode((601, 400))
#       5 running = True
# ----> 7 Coin_Flip(running, font)
#      10 # Displaying Text
#      11 font = py.font.SysFont('timesnewroman.ttf', 30)
#
# NameError: name 'font' is not defined
